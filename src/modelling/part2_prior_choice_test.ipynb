# %%
import arviz as az
import matplotlib.pyplot as plt
import tensorflow_probability as tfp
import numpy as np
import pandas as pd
import pymc as pm
import xarray as xr
import seaborn as sns
from pymc import HalfCauchy, Model, Normal, sample

print(f"Running on PyMC v{pm.__version__}")
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Running on PyMC v5.6.1

# %%
from pipeline import import_data, base_process_data, feature_normalization, ensemble_predict, temporal_process_data
from utils import cd_root_dir, save2Vis
from modules import pl_priorNposterior

# %%
cd_root_dir()
# Out:
# current directory: /home/yuchen/work_leslie/KTP_Croud

# %%
# %config InlineBackend.figure_format = 'retina'
# # Initialize random number generator
RANDOM_SEED = 9527
rng = np.random.default_rng(RANDOM_SEED)
az.style.use("arviz-darkgrid")

# %%
# set up a global plt style for the script

plt.rcParams.update({
        "font.size": 9,
        "text.usetex": True,
        "font.family": "serif",
        "figure.figsize": (4, 3),
        "legend.fontsize": 'medium',
        })

# %%
# import the data and get the time axis !
dataset, time_axis = import_data(path='data/raw/weekly_media_sample.csv')

# %%
# normalized features
n_train_features, n_test_features, train_labels, test_labels = base_process_data(dataset=dataset, split_index=200, normalize=True)

# %%
dataset.head()
# Out:
#     revenue  media1_S      media2_S      media3_S  competitor_sales  \
# 0  2.754372  167687.6   95463.66667  228213.98740           8125009
# 1  2.584277  214600.9       0.00000   34258.57351           7901549
# 2  2.547387       0.0    3404.00000  127691.26130           8300197
# 3  2.875220  625877.3  132600.00000   84014.72031           8122883
# 4  2.215953       0.0       0.00000   20687.47816           7105985
#
#    newsletter
# 0    19401.65
# 1    14791.00
# 2    14544.00
# 3     2800.00
# 4    15478.00

# %% [markdown]
# # generic weakly informative
#
# - without prior information; set up generic weakly informative prior as standard gaussian

# %%
with Model() as model:  # model specifications in PyMC are wrapped in a with-statement
    # Define priors
    sigma = pm.HalfNormal("sigma", sigma=10)
    b1 = Normal("media1_S", 0, sigma=1)
    b2 = Normal("media2_S", 0, sigma=1)
    b3 = Normal("media3_S", 0, sigma=1)
    b_cs = Normal("competitor_sales", 0, sigma=1)
    b_nl = Normal("newsletter", 0, sigma=1)
    bias = Normal("bias", 0, sigma=1)

    # Define likelihood
    likelihood = Normal("revenue", 
                        mu = bias +b1*n_train_features[:,0]+b2*n_train_features[:,1]+b3*n_train_features[:,2]+b_cs*n_train_features[:,3]+b_nl*n_train_features[:,4], 
                        sigma=sigma, 
                        observed=train_labels)

    # Inference!
    # draw 3000 posterior samples using NUTS sampling
    trace_0 = sample(5000, random_seed=RANDOM_SEED, return_inferencedata=True)

# %%
# idata.mean_tree_accept.mean()

# %%
az.plot_trace(trace_0, combined=True, figsize=(12, 24));

# %%
# .mean_tree_accept.mean()

# %%
### compare prior and posterior dist

# %%
# get the posterior of a coefficient

pos_dist = trace_0.posterior['media3_S'].to_numpy()[0]

# %%
prior_media3 = tfp.distributions.Normal(
    loc=0,
    scale=1,
    name='Normal')

# %%
# the posterior 
fig, ax = plt.subplots()
dummy_xaxis = np.linspace(-2, 2, 100)
ax.plot(dummy_xaxis, prior_media3.prob(dummy_xaxis), color='green', label='prior')
sns.histplot(x=pos_dist, bins=10, kde=True, stat='density', label='posterior', ax=ax)
ax.legend()
save2Vis('posterior_media3')

# %%
#### predictive posterior check

# %%
with model:
    ppc = pm.sample_posterior_predictive(
        trace_0, var_names=["revenue"], random_seed=RANDOM_SEED)

# %%
ppc.posterior_predictive

# %%
# let me double check the marginal distribution of revenue
sns.kdeplot(ppc.observed_data.revenue)

# %%
az.plot_ppc(ppc, num_pp_samples=100);

# %%
# prediction

predictors_out_of_sample = rng.normal(size=50)
outcomes_out_of_sample = rng.binomial(
    1, logistic(true_intercept + true_slope * predictors_out_of_sample)
)

with model_2:
    # update values of predictors:
    pm.set_data({"pred": predictors_out_of_sample})
    # use the updated values and predict outcomes and probabilities:
    idata_2 = pm.sample_posterior_predictive(
        idata_2,
        var_names=["p"],
        return_inferencedata=True,
        predictions=True,
        extend_inferencedata=True,
        random_seed=rng,
    )

# %% [markdown]
# # 2b-1
#
# - If the expert is rather certain that `Media 3` has no impact, I'd therefore put a informative prior distribution that puts majority of density around 0.
# - For example, $\mathcal{N}(\mu=0, \sigma^2 = 0.04)$. with a $\sigma=0.2$. As such, roughly 95% density will be in the range of (-0.4, 0.4).

# %% [markdown]
# # 2b-2

# %%
with Model() as model_2b1:  # model specifications in PyMC are wrapped in a with-statement
    # Define priors
    sigma = pm.HalfNormal("sigma", sigma=10)
    b1 = Normal("media1_S", 0, sigma=1)
    b2 = Normal("media2_S", 0, sigma=1)
    b3 = Normal("media3_S", 0, sigma=0.2)
    b_cs = Normal("competitor_sales", 0, sigma=1)
    b_nl = Normal("newsletter", 0, sigma=1)
    bias = Normal("bias", 0, sigma=1)

    # Define likelihood
    likelihood = Normal("revenue", 
                        mu = bias +b1*n_train_features[:,0]+b2*n_train_features[:,1]+b3*n_train_features[:,2]+b_cs*n_train_features[:,3]+b_nl*n_train_features[:,4], 
                        sigma=sigma, 
                        observed=train_labels)

    # Inference!
    # draw 3000 posterior samples using NUTS sampling
    trace_2b1 = sample(5000)

# %%
az.plot_trace(trace_2b1, combined=True, figsize=(10, 20));

# %%
az.plot_forest(trace_2b1, var_names=["media3_S"], combined=True, hdi_prob=0.95, r_hat=False);
# save2Vis('media3_effect')

# %%
# see the prior and posterior distributions

# %%
# get the posterior of a coefficient

pos_dist = trace_2b1.posterior['media3_S'].to_numpy()[0]

# %%
prior_media3 = tfp.distributions.Normal(
    loc=0,
    scale=0.2,
    name='Normal')

# %%
# the posterior 
fig, ax = plt.subplots()
dummy_xaxis = np.linspace(-2, 2, 100)
ax.plot(dummy_xaxis, prior_media3.prob(dummy_xaxis), color='green', label='prior')
sns.histplot(x=pos_dist, bins=10, kde=True, stat='density', label='posterior', ax=ax)
ax.legend()
save2Vis('posterior_media3')

# %% [markdown]
# # 2b-3

# %% [markdown]
# - Strictly positive relationship suggests positive coefficient `newsletter` $\beta_{nl}$. As such, I will choose a **half-Gussian prior distribution**
# - “I am **fairly certain** that one unit invested in `Media 1` will result in two units of marketing revenues returned.”, ergo
# $\beta_{m1} \sim \mathcal{N}(2, 0.04)$ with $\sigma=0.2$
#
# - I believe the impact of `Media 2` is four times that of what I specified for `Media 1`. Ergo, $\beta_{m2} \sim N(8, 0.25)$
#
# - For every unit increase in `competitor_sales`, the change on revenues returned must range between 0 and 0.3. Ergo, a truncated distribution ..

# %%
with Model() as model_2b3:  # model specifications in PyMC are wrapped in a with-statement
    # Define priors
    sigma = pm.HalfNormal("sigma", sigma=10)
    
    b1 = Normal("media1_S", 2, sigma=0.2)
    b2 = Normal("media2_S", 8, sigma=0.5)
    b3 = Normal("media3_S", 0, sigma=0.2)
    # b_cs = pm.TruncatedNormal('competitor_sales', mu=0, sigma=1, lower=0, upper=0.3)
    b_cs = pm.Uniform('competitor_sales', upper=0.3)
    
    b_nl = pm.HalfNormal('newsletter', sigma=1)
    bias = Normal("bias", 0, sigma=1)

    # Define likelihood
    likelihood = Normal("revenue", 
                        mu = bias +b1*n_train_features[:,0]+b2*n_train_features[:,1]+b3*n_train_features[:,2]+b_cs*n_train_features[:,3]+b_nl*n_train_features[:,4], 
                        sigma=sigma, 
                        observed=train_labels)

    # Inference!
    # draw 5000 posterior samples using NUTS sampling
    trace_2b3 = sample(5000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, media1_S, media2_S, media3_S, competitor_sales, newsletter, bias]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='24000' class='' max='24000' style='width:300px; height:20px; vertical-align: middle;'></progress>
# ...

# %%
az.plot_trace(trace_2b3, combined=True, figsize=(10, 24));
# save2Vis('knowledge_prior_retrain')

# %% [markdown]
# ### closer look at the posterior

# %%
az.plot_forest(trace_2b3, var_names=["media1_S", "media2_S", "media3_S", "competitor_sales", "newsletter", ], combined=True, hdi_prob=0.95);
# save2Vis('posteior_hdi')

# %%
# get the prior, posterior, plot for each feature ....

# %%
prior_media1 = tfp.distributions.Normal(loc=2, scale=0.2, name='Normal')

# %%
pl_priorNposterior(trace_2b3, parameter='media1_S', prior_obj=prior_media1, low=1, high=3)

# %%
prior_media2 = tfp.distributions.Normal(loc=8, scale=0.5, name='Normal')
pl_priorNposterior(trace_2b3, parameter='media2_S', prior_obj=prior_media2, low=6, high=10)

# %% [markdown]
# ### posterior predictive check

# %%
with model_2b3:
    ppc = pm.sample_posterior_predictive(
        trace_2b3, var_names=["revenue"], random_seed=RANDOM_SEED)
# Out:
# Sampling: [revenue]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='20000' class='' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20000/20000 00:02&lt;00:00]
#     </div>

# %%
az.plot_ppc(ppc, num_pp_samples=200);
